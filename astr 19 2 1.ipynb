# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,1,100)
xfunction = np.exp(x)

# %%
y = np.exp(x)

f, axarr = plt.subplots(1, 1)
axarr.plot(x,y)
axarr.set_xlabel('Time [Miliseconds]')
axarr.set_ylabel('"Awesomeness"')
axarr.set_title('Arbitrary Title')

plt.savefig('project2_1.pdf',bbox_inches='tight',pad_inches=0,dpi=600)
